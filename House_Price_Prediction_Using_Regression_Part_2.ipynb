# %% [markdown]
# <a href="https://colab.research.google.com/github/cuaiswarya/Deep-Learning/blob/main/House_Price_Prediction_Using_Regression_Part_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ex-9 House Price Prediction Using Regression Part-2

# %%
import pandas as pd

# %%
housing = pd.read_csv("house_pricing.csv")

# %%
housing.head()
# Out:
#    housingMedianAge  totalRooms  ...  medianIncome  medianHouseValue
# 0              41.0       880.0  ...        8.3252          452600.0
# 1              21.0      7099.0  ...        8.3014          358500.0
# 2              52.0      1467.0  ...        7.2574          352100.0
# 3              52.0      1274.0  ...        5.6431          341300.0
# 4              52.0      1627.0  ...        3.8462          342200.0
#
# [5 rows x 7 columns]

# %%
housing.describe().transpose()
# Out:
#                     count           mean  ...           75%          max
# housingMedianAge  20640.0      28.639486  ...      37.00000      52.0000
# totalRooms        20640.0    2635.763081  ...    3148.00000   39320.0000
# totalBedrooms     20640.0     537.898014  ...     647.00000    6445.0000
# population        20640.0    1425.476744  ...    1725.00000   35682.0000
# households        20640.0     499.539680  ...     605.00000    6082.0000
# medianIncome      20640.0       3.870671  ...       4.74325      15.0001
# medianHouseValue  20640.0  206855.816909  ...  264725.00000  500001.0000
#
# [7 rows x 8 columns]

# %%
housing.isnull().sum()
# Out:
# housingMedianAge    0
# totalRooms          0
# totalBedrooms       0
# population          0
# households          0
# medianIncome        0
# medianHouseValue    0
# dtype: int64

# %%
x_data = housing.drop(['medianHouseValue'],axis=1)

# %%
y_val = housing['medianHouseValue']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data, y_val, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
scaler.fit(X_train)
# Out:
# MinMaxScaler()

# %%
X_train = pd.DataFrame(data=scaler.transform(X_train),columns=X_train.columns,index=X_train.index)
X_train.head()
# Out:
#       housingMedianAge  totalRooms  ...  households  medianIncome
# 6761          0.352941    0.069688  ...    0.115442      0.142508
# 3010          0.607843    0.011242  ...    0.014142      0.045027
# 7812          0.666667    0.025230  ...    0.030258      0.212866
# 8480          0.666667    0.032530  ...    0.030094      0.298651
# 1051          0.294118    0.031919  ...    0.034863      0.272631
#
# [5 rows x 6 columns]

# %%
X_test = pd.DataFrame(data=scaler.transform(X_test),columns=X_test.columns,index=X_test.index)
X_test.head()
# Out:
#        housingMedianAge  totalRooms  ...  households  medianIncome
# 16086          0.686275    0.046264  ...    0.048841      0.353133
# 8816           0.705882    0.027417  ...    0.023187      0.770182
# 7175           0.901961    0.032326  ...    0.042592      0.133626
# 16714          0.313725    0.043212  ...    0.048018      0.263576
# 14491          0.411765    0.088433  ...    0.072192      0.660046
#
# [5 rows x 6 columns]

# %%
housing.columns
# Out:
# Index(['housingMedianAge', 'totalRooms', 'totalBedrooms', 'population',
#        'households', 'medianIncome', 'medianHouseValue'],
#       dtype='object')

# %%
import tensorflow as tf

# %%
age = tf.feature_column.numeric_column('housingMedianAge')
rooms = tf.feature_column.numeric_column('totalRooms')
bedrooms = tf.feature_column.numeric_column('totalBedrooms')
pop = tf.feature_column.numeric_column('population')
households = tf.feature_column.numeric_column('households')
income = tf.feature_column.numeric_column('medianIncome')

# %%
feat_cols = [age,rooms,bedrooms,pop,households,income]

# %%
feat_cols
# Out:
# [NumericColumn(key='housingMedianAge', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='totalRooms', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='totalBedrooms', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='population', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='households', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None),
#  NumericColumn(key='medianIncome', shape=(1,), default_value=None, dtype=tf.float32, normalizer_fn=None)]

# %%
input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/lazy_loader.py:63: The name tf.estimator.inputs is deprecated. Please use tf.compat.v1.estimator.inputs instead.

# %%
model = tf.estimator.DNNRegressor(hidden_units=[8,8,8],feature_columns=feat_cols)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpzi3xz2cu
# INFO:tensorflow:Using config: {'_model_dir': '/tmp/tmpzi3xz2cu', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# ...

# %%
model.train(input_fn=input_func, steps=25000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Calling checkpoint listeners before saving checkpoint 0...
# INFO:tensorflow:Saving checkpoints for 0 into /tmp/tmpzi3xz2cu/model.ckpt.
# INFO:tensorflow:Calling checkpoint listeners after saving checkpoint 0...
# INFO:tensorflow:loss = 45254124000.0, step = 0
# INFO:tensorflow:global_step/sec: 445.479
# INFO:tensorflow:loss = 76998164000.0, step = 100 (0.230 sec)
# INFO:tensorflow:global_step/sec: 512.707
# INFO:tensorflow:loss = 66891907000.0, step = 200 (0.203 sec)
# INFO:tensorflow:global_step/sec: 500.218
# INFO:tensorflow:loss = 73548810000.0, step = 300 (0.190 sec)
# INFO:tensorflow:global_step/sec: 464.419
# INFO:tensorflow:loss = 103514210000.0, step = 400 (0.220 sec)
# INFO:tensorflow:global_step/sec: 489.39
# ...

# %%
predict_input_func = tf.compat.v1.estimator.inputs.pandas_input_fn(x=X_test,batch_size=10,num_epochs=1,shuffle=False)

# %%
pred_gen = model.predict(predict_input_func)

# %%
predictions = list(pred_gen)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from /tmp/tmpbfckqwt7/model.ckpt-25000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %%
predictions
# Out:
# [{'predictions': array([4.907562], dtype=float32)},
#  {'predictions': array([5.6256943], dtype=float32)},
#  {'predictions': array([4.801447], dtype=float32)},
#  {'predictions': array([4.133733], dtype=float32)},
#  {'predictions': array([5.2499657], dtype=float32)},
#  {'predictions': array([4.536461], dtype=float32)},
#  {'predictions': array([4.977968], dtype=float32)},
#  {'predictions': array([4.5773277], dtype=float32)},
#  {'predictions': array([4.593943], dtype=float32)},
#  {'predictions': array([3.9137657], dtype=float32)},
#  {'predictions': array([4.59697], dtype=float32)},
#  {'predictions': array([5.0010257], dtype=float32)},
#  {'predictions': array([4.357344], dtype=float32)},
#  {'predictions': array([4.0726857], dtype=float32)},
#  {'predictions': array([5.4302115], dtype=float32)},
#  {'predictions': array([3.9742494], dtype=float32)},
#  {'predictions': array([4.522612], dtype=float32)},
#  {'predictions': array([4.200159], dtype=float32)},
# ...

# %%
y_test
# Out:
# 16086    406200.0
# 8816     500001.0
# 7175     122900.0
# 16714    209100.0
# 14491    500001.0
#            ...
# 1263     162800.0
# 12815    225000.0
# 12139    136300.0
# 16208     60800.0
# 571      231000.0
# Name: medianHouseValue, Length: 6192, dtype: float64

# %%
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py:91: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-21c0cb3e7999> in <module>()
#       1 from sklearn.metrics import r2_score
#       2
# ----> 3 r2_score(y_test, predictions)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_regression.py in r2_score(y_true, y_pred, sample_weight, multioutput)
#     773     """
#     774     y_type, y_true, y_pred, multioutput = _check_reg_targets(
# --> 775         y_true, y_pred, multioutput
#     776     )
# ...
